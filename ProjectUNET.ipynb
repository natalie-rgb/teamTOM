# %% [markdown]
# <a href="https://colab.research.google.com/github/natalie-rgb/teamTOM/blob/master/ProjectUNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
! sudo apt-get install git-lfs
! git lfs install
! git clone https://github.com/neheller/kits19.git
# Out:
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 43 not upgraded.
# Need to get 6,877 kB of archives.
# After this operation, 16.4 MB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu bionic/main amd64 git-lfs amd64 2.11.0 [6,877 kB]
# ...

# %%
# %cd kits19
# !pip3 install -r /content/kits19/requirements.txt
! python -m starter_code.get_imaging
# Out:
# [Errno 2] No such file or directory: 'kits19'
# /content/kits19
# ...
# 291 cases to download...
# Download 1/291:
# case_00009: 100% 34134/34135 [00:03<00:00, 11229.21KB/s]
# Download 2/291:
# case_00010: 100% 23541/23542 [00:02<00:00, 11339.15KB/s]
# Download 3/291:
# case_00011: 100% 41268/41269 [00:03<00:00, 12021.46KB/s]
# Download 4/291:
# case_00012: 100% 43185/43186 [00:03<00:00, 12071.42KB/s]
# Download 5/291:
# case_00013: 100% 44485/44486 [00:03<00:00, 14593.67KB/s]
# Download 6/291:
# case_00014: 100% 192486/192487 [00:11<00:00, 16481.86KB/s]
# Download 7/291:
# case_00015: 100% 23795/23796 [00:02<00:00, 10193.66KB/s]
# Download 8/291:
# case_00016: 100% 86929/86930 [00:06<00:00, 14341.18KB/s]
# Download 9/291:
# case_00017: 100% 49940/49941 [00:03<00:00, 12500.86KB/s]
# Download 10/291:
# case_00018: 100% 49984/49985 [00:03<00:00, 13480.81KB/s]
# Download 11/291:
# case_00019: 100% 51644/51645 [00:03<00:00, 12983.73KB/s]
# Download 12/291:
# ...

# %%
# %cd /content/kits19/
# Out:
# /content/kits19

# %%
import os
train_path = "/content/kits19/data/case_00000/"

cases = next(os.walk(train_path))
file_name = cases[1]

# %%
cases
# Out:
# ('/content/kits19/data/case_00000/',
#  [],
#  ['segmentation.nii.gz', 'imaging.nii.gz'])

# %%
d = []
for image in os.listdir('/content/kits19/data/case_00000/'):
  d.append(image)

# %%
import nibabel as nib
img = nib.load('/content/kits19/data/case_00000/' + d[1])

# %%
file_name = cases[1]

# %%
file_name
# Out:
# []

# %%
cases
# Out:
# ('/content/kits19/data/case_00000/',
#  [],
#  ['segmentation.nii.gz', 'imaging.nii.gz'])

# %%
cases[-1][1]
# Out:
# 'imaging.nii.gz'

# %%
image_path = os.path.join(train_path, str(cases[-1][1]))

# %%
image_path
# Out:
# '/content/kits19/data/case_00000/imaging.nii.gz'

# %%
import nibabel as nib
img = nib.load(image_path)

# %%
img.shape
# Out:
# (611, 512, 512)

# %%
import numpy as np

image = np.array(img)
type(image)
data = img.get_fdata()
data.shape
type(data)
# Out:
# numpy.ndarray

# %%
print(img.slicer)

# %%
img.get_data_dtype() == np.dtype(np.float)
# Out:
# True

# %%
img.affine.shape
# Out:
# (4, 4)

# %%
data = img.get_fdata()

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (611, 512, 512)

# %%
import cv2
np.unique(data[21])
# Out:
# array([-1024., -1023., -1022., ...,  1208.,  1212.,  1238.])

# %%
img.header

# %%
import nibabel as nib
from nibabel.testing import data_path
img = nib.load(example_filename) #notness?
img.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-c4680a0bb3bd> in <module>()
#       1 import nibabel as nib
#       2 from nibabel.testing import data_path
# ----> 3 img = nib.load(example_filename)
#       4 img.shape
#
# NameError: name 'example_filename' is not defined

# %%
data = img.get_fdata()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
import matplotlib.pyplot as plt
plt.imshow(data[150,:,:])

# %%
import matplotlib.pyplot as plt
plt.imshow(data[15], cmap='gray')

# %%
# 

# image = cv2.imread(image_path, 1)

# %%
import keras
